# %%
import os, sys 
import pydicom as dicom
import numpy as np
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import glob
import shutil
import tensorflow as tf
import cv2
import pandas as pd


def importOwnLib():
    if '/home/miruware/aProjects/lib' not in sys.path:
        sys.path.append('/home/miruware/aProjects/lib')
        print("lib path is successfully appended.")
    else:
        print("lib path is already exists.")

importOwnLib()
import sonyalib as sonya

import importlib
importlib.reload(sonya)

# %%
def get_windowing(data):
    if 'RescaleSlope' in data:
        dicom_fields = [data[('0028','1050')].value, #window center
                        data[('0028','1051')].value, #window width
                        data[('0028','1052')].value, #intercept
                        data[('0028','1053')].value] #slope
    else:
        dicom_fields = [data[('0028','1050')].value, #window center
                        data[('0028','1051')].value, #window width
                        0, #intercept
                        1] #slope
    return [get_first_of_dicom_field_as_int(x) for x in dicom_fields]


def window_image(img, window_center,window_width, intercept, slope):
    img = (img * slope + intercept)
    img_min = window_center - window_width//2
    img_max = window_center + window_width//2 
    
    img[img <= img_min] = img_min
    img[img > img_max] = img_max
    
    return img 


def get_first_of_dicom_field_as_int(x):
    #get x[0] as in int is x is a 'pydicom.multival.MultiValue', otherwise get int(x)
    if type(x) == dicom.multival.MultiValue:
        return int(x[0])
    else:
        return int(x)


def dcm2img(dcm, mode=None):
    window_center , window_width, intercept, slope = get_windowing(dcm)
    print(window_center , window_width, intercept, slope)
    image_windowed = window_image(dcm.pixel_array, window_center, window_width, intercept, slope)
    if mode == 'RGB' or 'rgb':
        img_gray = Image.fromarray(image_windowed).convert('L')
        img_result = Image.merge("RGB", (img_gray, img_gray, img_gray))
    else:
        img_result = Image.fromarray(image_windowed).convert('L')

    return img_result

def search_ref_dcm(nUID, nPath):
    # nUID : referenced dcm UID of annotation object
    # nPath : path to case which currently working on
    # return: PIL Image (pixel_array from dcm)
    for series_nonQ in [list_series for list_series in os.listdir(nPath) if list_series.find('Q') < 0 and not list_series.startswith('.')]:  # iterate series except Q series
        for nDcm in [list_dcm for list_dcm in os.listdir(os.path.join(PATH_SERIES, series_nonQ)) if list_dcm.endswith('.dcm')]:  # check extension
            with dicom.read_file(os.path.join(PATH_SERIES, series_nonQ, nDcm)) as dcm:
                if dcm.SOPInstanceUID == matching_uid:  # searching target dcm with Q
                    img_ans = dcm2img(dcm, mode='RGB')  # create new images for answer
                    return img_ans, series_nonQ, nDcm
    
                
def search_ref_dcm_name(nUID, nPath, dPath):
    # nUID : referenced dcm UID of annotation object
    # nPath : path to case which currently working on
    # return: PIL Image (pixel_array from dcm)
    for series_nonQ in [list_series for list_series in os.listdir(nPath) if list_series.find('Q') < 0 and not list_series.startswith('.')]:  # iterate series except Q series
        for nDcm in [list_dcm for list_dcm in os.listdir(os.path.join(nPath, series_nonQ)) if list_dcm.endswith('.dcm')]:  # check extension
            abspath = os.path.join(nPath, series_nonQ, nDcm)
            with dicom.read_file(abspath) as dcm:
                if dcm.SOPInstanceUID == matching_uid:  # searching target dcm with Q
                    return nDcm, abspath     
                else:
                    len_path = len(nPath.split('/'))
                    src = '/'.join(nPath.split('/')[0:len_path-1])
                    
                    if not os.path.exists(src):
                        print("There is no matching dicom file.")
                        shutil.copytree(src, dPath)  # move case to noQ directory
                    else:
                        return False, False
    
def getUID(path): ## path with Case Number
    for currentdir, dirs, files in os.walk(path):
        for file in files:
            if "Q" in file:
#                 print(file)
                return dicom.read_file(os.path.join(currentdir, file)).SOPInstanceUID

# %%
PATH_BASE = '/mnt/8TBDisk/KTL2020_Effusion/KTL2020_Effusion/'
PATH_noQ = '/mnt/8TBDisk/KTL2020_Effusion/noQ'
sonya.createFolder(PATH_noQ)
PATH_debug = '/mnt/8TBDisk/KTL2020_Effusion/debug_require'
sonya.createFolder(PATH_debug)
PATH_RESULT = '/mnt/8TBDisk/KTL2020_Effusion/result'
sonya.createFolder(PATH_RESULT)
PATH_PNG = '/mnt/8TBDisk/KTL2020_Effusion/png 변환/'


label_width = 10
arrow_width = 10

test_count = 0
for nPatient in [list_patient for list_patient in os.listdir(PATH_BASE) if not list_patient.startswith('.')]:

    PATH_PATIENT = os.path.join(PATH_BASE, nPatient)
    UID_check = []
#     print(PATH_PATIENT, "+++++")
    for nCase in [list_case for list_case in os.listdir(PATH_PATIENT) if not list_case.startswith('.')]:  # search Q file series
        PATH_CASE = os.path.join(PATH_PATIENT, nCase)
        # 여기서 중복체크가 이루어 져야 함.
        
        #####=============================================############
        if len([list_SeriesQ for list_SeriesQ in os.listdir(PATH_CASE) if list_SeriesQ.find('Q') >=0]) == 0: # check no Q cases
#             PATH_SERIES = os.path.join(PATH_CASE, )
#             move to non-Q directory
            shutil.move(PATH_CASE, os.path.join(PATH_noQ, nPatient, nCase))  # move case to noQ directory
            if len(os.listdir(PATH_PATIENT)) == 0: # Q파일이 없는 케이스를 옮겼는데 해당 환자폴더에 더이상 케이스가 남지 않은 경우, 해당 환자폴더 삭제
                os.rmdir(PATH_PATIENT)
        else: # chaeck overlapping cases
            currentUID = getUID(PATH_CASE)
            if currentUID in UID_check:
                print("there is overlapping cases." + os.path.join(nPatient, nCase))

            else: # extract Q file
                UID_check.append(currentUID) # SAVE CURRENT UID IN LOG
                nSeriesQ = [list_SeriesQ for list_SeriesQ in sorted(os.listdir(PATH_CASE)) if list_SeriesQ.find('Q') >=0][-1] # get latest q file

                PATH_SERIES = os.path.join(PATH_CASE, nSeriesQ)
                for nQ in [list_Q for list_Q in os.listdir(PATH_SERIES) if list_Q.endswith('.dcm')]:  # iterate all Q(dcm) file
                    dcm_q = dicom.read_file(os.path.join(PATH_SERIES, nQ))
                    if "GraphicAnnotationSequence" in dcm_q:
                        for nAnnotation in range(len(dcm_q.GraphicAnnotationSequence)):
                            # ================================= Searching Referenced SOP Instance UID to match dicom file ===============================
                            matching_uid = dcm_q.GraphicAnnotationSequence[nAnnotation].ReferencedImageSequence[0].ReferencedSOPInstanceUID
#                                 if matching_uid not in UID_check:
#                                     UID_check.append(matching_uid)
#                                 else:
#                                     print("there is overlapping cases." + os.path.join(nPatient, nCase))
#                             print(PATH_CASE)
                            
                            name_dcm, path_dcm = search_ref_dcm_name(matching_uid, PATH_CASE, os.path.join(PATH_debug, nPatient)) # matched dcm image name per annotation sequence
#                               print(name_dcm)
#                                 name_png = name_dcm.replace('.dcm','.png')
                            if name_dcm:
                                img_ans = Image.open(os.path.join(PATH_PNG, name_dcm.replace('.dcm','.png'))) # RGB 이미지
                                img_black = Image.new(mode="RGB", size = img_ans.size, color=(0,0,0)) # Black 이미지

                                # ========= Label Drawing =========
                                draw_rgb = ImageDraw.Draw(img_ans)
                                draw_black = ImageDraw.Draw(img_black) # draw RED label

                                if "GraphicObjectSequence" in dcm_q.GraphicAnnotationSequence[nAnnotation]:
                                    for nA_Object in range(len(dcm_q.GraphicAnnotationSequence[nAnnotation].GraphicObjectSequence)):
                                        #print(nDcm + "\t" + dcm_q.GraphicAnnotationSequence[nAnnotation].GraphicObjectSequence[nA_Object].GraphicType)
                                        obj_shape = dcm_q.GraphicAnnotationSequence[nAnnotation].GraphicObjectSequence[nA_Object].NumberOfGraphicPoints
                                        obj_graphic_data = dcm_q.GraphicAnnotationSequence[nAnnotation].GraphicObjectSequence[nA_Object].GraphicData

                                        if obj_shape == 2:  #
                                            print("Object shape is Circle - pass")
#                                             draw_rgb.ellipse(obj_graphic_data, width=label_width, outline="red")
#                                             draw_black.ellipse(obj_graphic_data, width=label_width, outline="red")
#                                            # img = Image.alpha_composite(answer_img, answer_back)
                                        elif obj_shape == 4:  # Ellipse/Oval 타원
                                            print("Object shape is Ellipse")
                                            #  ellipse_data = []
                                            obj_pt_X = sorted(obj_graphic_data[::1])
                                            obj_pt_Y = sorted(obj_graphic_data[1::2])
                                            ellipse_data = [min(obj_pt_X), min(obj_pt_Y), max(obj_pt_X), max(obj_pt_Y)]
                                            draw_rgb.ellipse(list(map(int, ellipse_data)), width=label_width, outline="red")
                                            draw_black.ellipse(list(map(int, ellipse_data)), width=label_width, outline="red")

                                            # img = Image.alpha_composite(answer_img, answer_back)
                                        elif obj_shape == 5 or 1:  # Polyline/Rect 자유곡선
                                            print("Object shape is Polyline")
                                            polyline_data = []
                                            for i in range(obj_shape):
                                                polyline_data.append(tuple(obj_graphic_data[i*2:i*2+2]))
                                            draw_rgb.line(polyline_data, width=label_width, fill='red', joint='curve')
                                            draw_black.line(polyline_data, width=label_width, fill='red', joint='curve')

                                          #  img = Image.alpha_composite(answer_img, answer_back)
                                        else:  # Polygon 다각형
                                            print("Object shape is Polygon")
                                            print(obj_shape, "\t", obj_graphic_data)
                                            draw_rgb.polygon(obj_graphic_data, outline='red')
                                            draw_black.polygon(obj_graphic_data, outline='red')


                                draw_rgb_name = os.path.join(PATH_RESULT, nQ.split('.')[0] + "_RGB.png") # rgb 저장
                                draw_black_name = os.path.join(PATH_RESULT, nQ.split('.')[0] + "_black.png") # black 저장
                                shutil.copy(path_dcm, PATH_RESULT) # 원본영상 복사
                                print(draw_rgb_name)

                                img_ans.save(draw_rgb_name)
                                img_black.save(draw_black_name)

    #####==========================================###########
         
            
            
            
#
# Out:
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100516_Q-20210119114629_14490883_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100315_Q-20210121095557_14490282_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100316_Q-20210121095616_14490283_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101009_Q-20210120101315_14492426_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101068_Q-20210122114920_14492635_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102942_Q-20210121102824_14501729_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101218_Q-20210122100857_14493402_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100610_Q-20210120100210_14491233_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102977_Q-20210120104315_14501946_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102672_Q-20210122104138_14499962_0002_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103040_Q-20210119095607_14502257_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101439_Q-20210120104346_14494048_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100953_Q-20210120101557_14492333_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102563_Q-20210121124315_14499453_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101486_Q-20210121130341_14494189_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100742_Q-20210122102423_14491710_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101421_Q-20210120101309_14494001_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103138_Q-20210120101538_14502605_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100662_Q-20210120101336_14491420_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103150_Q-20210120101944_14502659_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100660_Q-20210120101529_14491414_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100661_Q-20210120101609_14491419_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101521_Q-20210122102141_14494297_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101525_Q-20210122102144_14494306_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102636_Q-20210121112349_14499758_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100995_Q-20210120101822_14492408_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103056_Q-20210120101114_14502307_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100745_Q-20210121130415_14491728_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100707_Q-20210121124312_14491579_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100598_Q-20210121125238_14491189_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101342_Q-20210120124723_14493772_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101338_Q-20210120124719_14493762_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103136_Q-20210119081736_14502584_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103074_Q-20210120124934_14502379_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100647_Q-20210120124641_14491369_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103562_Q-20210120124911_14504834_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100510_Q-20210121110824_14490864_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100693_Q-20210120105704_14491534_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100600_Q-20210118133653_14491195_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103131_Q-20210119105325_14502561_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100537_Q-20210122104121_14490984_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100556_Q-20210120103211_14491065_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103124_Q-20210121095809_14502535_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103527_Q-20210122100941_14504652_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101395_Q-20210119104709_14493925_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100340_Q-20210118133624_14490381_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101063_Q-20210121125217_14492622_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102646_Q-20210121124352_14499817_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# /mnt/8TBDisk/KTL2020_Effusion/result/101427_Q-20210120101929_14494019_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100429_Q-20210122103356_14490663_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100432_Q-20210121130242_14490671_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100769_Q-20210122103558_14491813_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103120_Q-20210119101011_14502518_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101415_Q-20210120104408_14493980_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101151_Q-20210121112423_14493077_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101539_Q-20210122110021_14494342_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103477_Q-20210120125100_14504503_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100630_Q-20210120101123_14491306_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101061_Q-20210119113542_14492615_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103549_Q-20210122103725_14504754_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103595_Q-20210119081815_14505033_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102690_Q-20210121130358_14500047_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101330_Q-20210120124842_14493745_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103600_Q-20210120115702_14505054_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100525_Q-20210120124732_14490912_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100527_Q-20210119114601_14490915_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100807_Q-20210119085052_14491958_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100684_Q-20210121095837_14491499_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100767_Q-20210121130248_14491802_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101136_Q-20210122104116_14492967_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103017_Q-20210122113908_14502174_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101334_Q-20210120124523_14493752_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100570_Q-20210119084225_14491116_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102777_Q-20210119114653_14500686_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101534_Q-20210122113407_14494336_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100299_Q-20210119103238_14490233_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100301_Q-20210119104723_14490235_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100309_Q-20210120124708_14490266_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100305_Q-20210119105339_14490242_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100692_Q-20210118133649_14491533_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100303_Q-20210120104442_14490238_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100695_Q-20210118133643_14491542_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100635_Q-20210119110011_14491322_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103137_Q-20210119105322_14502585_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102989_Q-20210120124923_14502029_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101219_Q-20210120111958_14493403_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100813_Q-20210119101149_14491970_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100763_Q-20210122102128_14491797_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100438_Q-20210122114616_14490702_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100996_Q-20210120101105_14492410_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100502_Q-20210122110107_14490847_0002_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100364_Q-20210120124422_14490458_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100974_Q-20210120125042_14492368_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100427_Q-20210118133605_14490659_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100430_Q-20210118133640_14490664_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103458_Q-20210122113826_14504437_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100978_Q-20210120101816_14492378_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103459_Q-20210122113451_14504439_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100799_Q-20210119085058_14491926_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100608_Q-20210119102757_14491225_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100620_Q-20210119103328_14491256_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103601_Q-20210121124459_14505057_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100829_Q-20210119101646_14492021_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100656_Q-20210119105331_14491398_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100648_Q-20210120125139_14491372_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101205_Q-20210122095613_14493355_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100324_Q-20210119114322_14490322_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100785_Q-20210121102340_14491856_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101340_Q-20210120101242_14493767_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101160_Q-20210119104008_14493134_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101542_Q-20210122115027_14494351_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103003_Q-20210120101235_14502104_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103194_Q-20210122114701_14502839_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103020_Q-20210122113837_14502180_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103512_Q-20210119084350_14504600_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100557_Q-20210119103323_14491066_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103101_Q-20210119084219_14502463_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103507_Q-20210120124937_14504578_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101323_Q-20210121124300_14493699_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103057_Q-20210121100157_14502308_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102639_Q-20210119114300_14499767_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100590_Q-20210120124612_14491169_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102621_Q-20210120124354_14499687_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102961_Q-20210122114845_14501865_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100468_Q-20210120101138_14490772_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103172_Q-20210121095900_14502742_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100592_Q-20210119102731_14491174_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101538_Q-20210122104039_14494341_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101440_Q-20210121095147_14494050_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101088_Q-20210122102426_14492725_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101211_Q-20210122103603_14493391_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101035_Q-20210119110252_14492463_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101217_Q-20210122104055_14493399_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101489_Q-20210122102131_14494198_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100848_Q-20210119101809_14492063_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103118_Q-20210119101035_14502515_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100331_Q-20210120124416_14490351_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103030_Q-20210121095150_14502224_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103496_Q-20210122103644_14504550_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101203_Q-20210122102147_14493346_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101448_Q-20210120125047_14494081_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100478_Q-20210121102833_14490802_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101417_Q-20210119112301_14493987_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100514_Q-20210121125246_14490873_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100727_Q-20210118133732_14491654_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100371_Q-20210121124503_14490478_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103158_Q-20210121095520_14502687_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100450_Q-20210122113940_14490726_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100622_Q-20210119084343_14491260_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100642_Q-20210119105944_14491353_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103177_Q-20210122100928_14502753_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103563_Q-20210121110735_14504845_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100410_Q-20210119105319_14490617_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102727_Q-20210121125329_14500286_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100320_Q-20210119103106_14490309_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101260_Q-20210119103453_14493522_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100738_Q-20210121130230_14491698_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102983_Q-20210119113035_14501975_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100294_Q-20210119114632_14490214_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100551_Q-20210120125156_14491047_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101346_Q-20210120103147_14493781_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100519_Q-20210122113341_14490892_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100657_Q-20210121112629_14491399_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100975_Q-20210120124619_14492369_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103181_Q-20210121125232_14502769_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103188_Q-20210121124401_14502793_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101500_Q-20210121124359_14494227_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100458_Q-20210122104058_14490742_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100801_Q-20210119101002_14491940_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103107_Q-20210120113942_14502484_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103526_Q-20210120124630_14504650_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101284_Q-20210119103310_14493593_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101060_Q-20210122102432_14492614_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103061_Q-20210121124320_14502318_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100576_Q-20210121124129_14491125_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100298_Q-20210119110249_14490226_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101043_Q-20210120124558_14492537_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103038_Q-20210121102334_14502251_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101173_Q-20210120124504_14493189_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101105_Q-20210121095527_14492806_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101423_Q-20210120105807_14494006_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103130_Q-20210119081601_14502560_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101424_Q-20210121102337_14494007_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101480_Q-20210121130349_14494174_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103117_Q-20210119084206_14502509_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102587_Q-20210122101027_14499530_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100768_Q-20210122113404_14491806_0001_RGB.png
# Object shape is Circle - pass
# /mnt/8TBDisk/KTL2020_Effusion/result/102974_Q-20210120110903_14501941_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102668_Q-20210121100249_14499940_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103483_Q-20210121095637_14504514_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103096_Q-20210119112343_14502443_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103090_Q-20210119102655_14502433_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101240_Q-20210121100131_14493469_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100412_Q-20210122103402_14490620_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100408_Q-20210122103719_14490611_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101069_Q-20210121130456_14492636_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100774_Q-20210119084420_14491834_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100981_Q-20210120101804_14492383_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100980_Q-20210120105755_14492382_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102713_Q-20210121130312_14500206_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100403_Q-20210122100939_14490598_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100333_Q-20210121095356_14490354_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100327_Q-20210120112006_14490336_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103104_Q-20210119095603_14502473_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100819_Q-20210119100953_14491997_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100696_Q-20210120104417_14491544_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100547_Q-20210119102132_14491040_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100815_Q-20210119101637_14491987_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101470_Q-20210121100246_14494136_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103529_Q-20210119103932_14504659_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101131_Q-20210122103623_14492947_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103471_Q-20210121111438_14504481_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101460_Q-20210121112425_14494116_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100511_Q-20210122102332_14490868_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100762_Q-20210122114630_14491778_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100343_Q-20210119114343_14490389_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100584_Q-20210121095851_14491152_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101473_Q-20210121130409_14494141_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101505_Q-20210121130315_14494250_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100573_Q-20210121095627_14491119_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101322_Q-20210120110812_14493694_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101233_Q-20210122100924_14493451_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100401_Q-20210122102415_14490595_0002_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100400_Q-20210122103349_14490592_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100778_Q-20210119084414_14491841_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100380_Q-20210121130233_14490511_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100392_Q-20210122102450_14490561_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102973_Q-20210119102744_14501940_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101193_Q-20210121125326_14493305_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100599_Q-20210118133558_14491194_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103179_Q-20210122095602_14502765_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103062_Q-20210121100252_14502333_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103182_Q-20210121124348_14502770_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101358_Q-20210120110906_14493816_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102994_Q-20210120100121_14502058_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100603_Q-20210119081621_14491209_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101499_Q-20210122104017_14494223_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101493_Q-20210122102236_14494214_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101278_Q-20210122103514_14493569_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102800_Q-20210122095705_14500863_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100956_Q-20210120110120_14492340_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100993_Q-20210121125250_14492403_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103099_Q-20210122095554_14502448_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100545_Q-20210119112305_14491035_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101247_Q-20210120101535_14493485_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101515_Q-20210122113354_14494283_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101329_Q-20210120124501_14493722_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102593_Q-20210122114652_14499572_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100443_Q-20210122114655_14490712_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101092_Q-20210119114340_14492764_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101236_Q-20210120110849_14493465_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103083_Q-20210119105959_14502399_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101257_Q-20210120124231_14493513_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100328_Q-20210120101253_14490337_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103597_Q-20210119081618_14505046_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102667_Q-20210121130450_14499939_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101103_Q-20210121130444_14492803_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103142_Q-20210121111423_14502631_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100362_Q-20210121102827_14490439_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100365_Q-20210119105859_14490459_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100302_Q-20210119112040_14490236_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100479_Q-20210120113933_14490804_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100754_Q-20210119084411_14491743_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100753_Q-20210119084411_14491743_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103190_Q-20210121130459_14502824_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100986_Q-20210119104404_14492392_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100947_Q-20210119103337_14492323_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102596_Q-20210119081803_14499580_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101188_Q-20210121111358_14493285_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100617_Q-20210121130519_14491253_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100712_Q-20210121104439_14491605_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100605_Q-20210118133647_14491218_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101282_Q-20210120103134_14493583_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103500_Q-20210122114647_14504560_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100422_Q-20210121095550_14490648_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100420_Q-20210121095612_14490641_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103565_Q-20210120101935_14504856_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100231_Q-20210119101021_14490053_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103530_Q-20210119085046_14504661_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102663_Q-20210120124845_14499916_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103126_Q-20210119084328_14502543_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100595_Q-20210119110021_14491179_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101265_Q-20210122095641_14493535_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101258_Q-20210122095656_14493516_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103174_Q-20210121125332_14502748_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100638_Q-20210120103143_14491339_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100609_Q-20210119101749_14491232_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101062_Q-20210120124213_14492616_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100426_Q-20210119101032_14490651_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101064_Q-20210120124208_14492633_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100416_Q-20210119102121_14490630_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100544_Q-20210118133735_14491024_0002_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103535_Q-20210120124615_14504702_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100389_Q-20210122102417_14490549_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101031_Q-20210120125108_14492459_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101041_Q-20210120125144_14492536_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100436_Q-20210122114649_14490691_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102592_Q-20210122114938_14499571_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102589_Q-20210122114951_14499552_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100846_Q-20210119102624_14492060_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100313_Q-20210120104336_14490281_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101143_Q-20210120104332_14493055_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101535_Q-20210122113955_14494337_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103123_Q-20210120113936_14502533_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103449_Q-20210122113903_14504406_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102661_Q-20210122114910_14499914_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100235_Q-20210118133658_14490097_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100342_Q-20210120122939_14490387_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101226_Q-20210119112406_14493434_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103467_Q-20210120100152_14504472_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102991_Q-20210121095827_14502051_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103605_Q-20210121124506_14505070_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100756_Q-20210119084334_14491763_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100378_Q-20210121130307_14490499_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101106_Q-20210122113845_14492807_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101273_Q-20210119103447_14493551_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101108_Q-20210119112947_14492811_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101375_Q-20210119103244_14493871_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102728_Q-20210119101731_14500321_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103493_Q-20210121112835_14504542_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102725_Q-20210119101747_14500257_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102934_Q-20210121111435_14501678_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103165_Q-20210120104355_14502711_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100308_Q-20210120101034_14490257_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103551_Q-20210121130252_14504770_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100500_Q-20210121125253_14490840_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101183_Q-20210119113550_14493276_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100669_Q-20210118133633_14491449_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101366_Q-20210119104101_14493842_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100535_Q-20210121112414_14490969_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102599_Q-20210119084228_14499607_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100585_Q-20210119103953_14491153_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103014_Q-20210120101129_14502163_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101492_Q-20210122100931_14494203_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101363_Q-20210119104440_14493835_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100341_Q-20210119104811_14490386_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102568_Q-20210119112052_14499466_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101239_Q-20210121112602_14493468_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100509_Q-20210122103629_14490863_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101430_Q-20210121130453_14494028_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100291_Q-20210120100207_14490204_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100368_Q-20210121130304_14490473_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101422_Q-20210120124839_14494004_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101523_Q-20210122103648_14494303_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103622_Q-20210119084209_14505122_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102623_Q-20210119103929_14499695_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101010_Q-20210119110243_14492428_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100939_Q-20210119103320_14492310_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102631_Q-20210119104703_14499737_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100971_Q-20210119104718_14492361_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100994_Q-20210121112404_14492405_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102590_Q-20210120110053_14499560_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100339_Q-20210120101040_14490380_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102595_Q-20210119101136_14499578_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100690_Q-20210120125302_14491524_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101150_Q-20210119102925_14493075_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100992_Q-20210119104741_14492400_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101479_Q-20210122095650_14494172_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100534_Q-20210121111338_14490968_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103151_Q-20210120110129_14502660_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100664_Q-20210121100113_14491425_0002_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100665_Q-20210120124907_14491426_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103161_Q-20210121101917_14502696_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100717_Q-20210119081745_14491626_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101187_Q-20210119105843_14493287_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100629_Q-20210120124245_14491297_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100497_Q-20210122103701_14490834_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100384_Q-20210121110848_14490521_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101147_Q-20210121125214_14493064_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100480_Q-20210119101602_14490809_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101080_Q-20210122114619_14492692_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101292_Q-20210120101012_14493614_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100604_Q-20210119102759_14491213_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100523_Q-20210119114650_14490908_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100526_Q-20210120100129_14490913_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100522_Q-20210120125136_14490907_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100524_Q-20210121100242_14490909_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103545_Q-20210120101600_14504744_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100577_Q-20210120122955_14491131_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102993_Q-20210121112551_14502057_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101477_Q-20210122100934_14494168_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100307_Q-20210120122856_14490245_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101339_Q-20210119110347_14493765_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# ...
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101162_Q-20210119103407_14493138_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101157_Q-20210119103949_14493107_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103081_Q-20210119103410_14502393_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100385_Q-20210121130344_14490531_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100542_Q-20210119101014_14491021_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100437_Q-20210122113433_14490701_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101206_Q-20210120101046_14493356_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101298_Q-20210119103400_14493632_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100409_Q-20210122095414_14490615_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103070_Q-20210122095637_14502362_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100292_Q-20210120103221_14490208_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101413_Q-20210120124712_14493972_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100322_Q-20210119104045_14490319_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103042_Q-20210120110839_14502260_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100321_Q-20210121100109_14490315_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100349_Q-20210119104112_14490411_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103043_Q-20210119105956_14502262_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100347_Q-20210119112308_14490410_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101011_Q-20210120101524_14492430_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103508_Q-20210120104339_14504579_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101319_Q-20210120100201_14493686_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101207_Q-20210119110003_14493374_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103077_Q-20210119084156_14502384_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103076_Q-20210119102148_14502382_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100531_Q-20210119103334_14490933_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101025_Q-20210120124849_14492448_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101078_Q-20210122102150_14492690_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102971_Q-20210121124111_14501939_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102968_Q-20210122100958_14501905_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101190_Q-20210120124853_14493291_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101267_Q-20210121101949_14493539_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101261_Q-20210121102003_14493528_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101272_Q-20210121110846_14493550_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101271_Q-20210121110728_14493549_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103102_Q-20210119101614_14502467_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103022_Q-20210120122948_14502183_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101442_Q-20210121112420_14494057_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100713_Q-20210120124636_14491606_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101516_Q-20210122101011_14494284_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103455_Q-20210120104426_14504429_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100397_Q-20210122102125_14490573_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101038_Q-20210122095355_14492513_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101454_Q-20210121111333_14494095_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103028_Q-20210120101932_14502211_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101066_Q-20210119114020_14492630_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101079_Q-20210120100204_14492691_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100618_Q-20210120110910_14491255_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100457_Q-20210122113351_14490741_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103491_Q-20210121130418_14504540_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101033_Q-20210120101925_14492460_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100616_Q-20210119084324_14491247_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103569_Q-20210121130318_14504868_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100812_Q-20210119101643_14491969_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103481_Q-20210119104751_14504512_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103528_Q-20210121095554_14504653_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100826_Q-20210119101623_14492014_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103492_Q-20210122103552_14504547_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103164_Q-20210121111416_14502701_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100802_Q-20210119101711_14491952_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100985_Q-20210120105700_14492390_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100363_Q-20210119101130_14490449_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102972_Q-20210120123952_14501938_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103132_Q-20210122115009_14502569_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101248_Q-20210122104150_14493491_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101290_Q-20210122115006_14493612_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102796_Q-20210118133608_14500831_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103095_Q-20210119111955_14502442_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101048_Q-20210120124823_14492552_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102944_Q-20210121125229_14501731_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102572_Q-20210121111432_14499482_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100559_Q-20210122103555_14491079_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100346_Q-20210120125148_14490403_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100625_Q-20210119103436_14491272_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101522_Q-20210122102309_14494302_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101524_Q-20210122104013_14494305_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101230_Q-20210120101322_14493445_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100627_Q-20210119101752_14491279_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101474_Q-20210122104128_14494150_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103456_Q-20210122102230_14504436_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102790_Q-20210122102227_14500759_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101140_Q-20210120124250_14492999_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103073_Q-20210120125050_14502370_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103111_Q-20210122101018_14502492_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100865_Q-20210119102712_14492118_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100804_Q-20210119101138_14491955_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100735_Q-20210121130330_14491692_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102628_Q-20210121130352_14499722_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101357_Q-20210120103140_14493815_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101354_Q-20210119114555_14493803_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101356_Q-20210120104321_14493813_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101536_Q-20210122103600_14494339_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100344_Q-20210120101809_14490396_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101487_Q-20210122105954_14494191_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100317_Q-20210121095547_14490290_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103100_Q-20210119081640_14502459_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103024_Q-20210121101958_14502199_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103027_Q-20210121102006_14502210_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103596_Q-20210118133701_14505036_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103544_Q-20210122102420_14504736_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101225_Q-20210122115000_14493432_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101382_Q-20210119112049_14493889_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101158_Q-20210121101932_14493108_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101511_Q-20210122100911_14494280_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101485_Q-20210122114913_14494186_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103113_Q-20210119084145_14502495_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103484_Q-20210120105655_14504515_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103485_Q-20210120105652_14504517_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100472_Q-20210122100854_14490790_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101122_Q-20210122104135_14492848_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100983_Q-20210120101550_14492386_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101418_Q-20210121095144_14493988_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101243_Q-20210122103446_14493473_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101313_Q-20210119114257_14493673_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101310_Q-20210119111917_14493665_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101508_Q-20210122100914_14494257_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101113_Q-20210121125320_14492828_0001_RGB.png
# Object shape is Circle - pass
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101117_Q-20210122113344_14492832_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101528_Q-20210122104020_14494318_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102591_Q-20210122103423_14499561_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103533_Q-20210120110816_14504677_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103555_Q-20210122113923_14504776_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/100508_Q-20210120101616_14490862_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101036_Q-20210121130420_14492467_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/102686_Q-20210121130412_14500031_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/101325_Q-20210120115659_14493702_0001_RGB.png
# Object shape is Polyline
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103067_Q-20210121112829_14502359_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103558_Q-20210122103358_14504790_0001_RGB.png
# Object shape is Polyline
# /mnt/8TBDisk/KTL2020_Effusion/result/103525_Q-20210121125226_14504648_0001_RGB.png
