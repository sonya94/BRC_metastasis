# %%
import warnings

warnings.filterwarnings(action='ignore')
import os, sys
import pandas as pd
import numpy as np

def importOwnLib():
    if '/home/miruware/aProjects/lib' not in sys.path:
        sys.path.append('/home/miruware/aProjects/lib')
        print("lib path is successfully appended.")
    else:
        print("lib path is already exists.")

importOwnLib()
import sonyalib as sonya

import importlib
importlib.reload(sonya)
from math import sqrt
import datetime
import timeit
import tensorflow as tf

from scipy import interp

import keras
from keras.optimizers import Adam
from keras import callbacks, losses

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, BatchNormalization, Dropout
from keras import initializers
from keras.backend.tensorflow_backend import set_session
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
## RFE
from sklearn.feature_selection import RFE, RFECV
from sklearn.model_selection import GridSearchCV, StratifiedKFold,train_test_split, KFold

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import auc, roc_curve
# Out:
# lib path is successfully appended.
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '1'
config = tf.ConfigProto()
config.gpu_options.allow_growth = True # GPU메모리가 전부 할당되지 않고, 아주 적은 비율만 할당되어 시작해서 프로세스의 메모리 수요에 따라 증가하게 된다.
config.gpu_options.visible_device_list = "0"
set_session(tf.Session(config=config))

def mlp_model(num_input, dropout=0, lr=0.005, l1=9, l2=9):
    keras.backend.clear_session()
    seed_number = 7
    ## 모델 구성하기
    model = Sequential()
    # print learning rate

    model.add(Dense(l1, activation='relu', input_dim=num_input, kernel_initializer=initializers.he_normal(seed=seed_number)))
    model.add(BatchNormalization())
    model.add(Dense(l2, activation='relu', kernel_initializer=initializers.he_normal(seed=seed_number)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    model.add(Dense(1, activation='sigmoid', kernel_initializer=initializers.he_normal(seed=seed_number)))

    ## 모델 컴파일
    model.compile(optimizer=Adam(lr), loss=losses.binary_crossentropy, metrics=['accuracy'])

    # model.summary()
    return model


def confusion_metrics(conf_matrix):
    # save confusion matrix and slice into four pieces
    TP = conf_matrix[1][1]
    TN = conf_matrix[0][0]
    FP = conf_matrix[0][1]
    FN = conf_matrix[1][0]
    print('True Positives:', TP)
    print('True Negatives:', TN)
    print('False Positives:', FP)
    print('False Negatives:', FN)

    # calculate accuracy
    conf_accuracy = (float(TP + TN) / float(TP + TN + FP + FN))

    # calculate mis-classification
    conf_misclassification = 1 - conf_accuracy

    # calculate the sensitivity
    conf_sensitivity = (TP / float(TP + FN))
    # calculate the specificity
    conf_specificity = (TN / float(TN + FP))

    # calculate precision
    conf_precision = (TN / float(TN + FP))
    # calculate f_1 score
    conf_f1 = 2 * ((conf_precision * conf_sensitivity) / (conf_precision + conf_sensitivity))
    print('-' * 50)
    print(f'Accuracy: {round(conf_accuracy, 2)}')
    print(f'Mis-Classification: {round(conf_misclassification, 2)}')
    print(f'Sensitivity: {round(conf_sensitivity, 2)}')
    print(f'Specificity: {round(conf_specificity, 2)}')
    print(f'Precision: {round(conf_precision, 2)}')
    print(f'f_1 Score: {round(conf_f1, 2)}')

    return conf_sensitivity,  conf_specificity

# %%
print("This is local file")

start_time = timeit.default_timer()  # 시작 시간 체크

# ==== Step 1. Load original dataset
file_path0 = './BRC_input_201116_train.xlsx'
file_path1 = './BRC_input_201116_test.xlsx'
meta_train = sonya.get_normalized_metadata(file_path0)
meta_test = sonya.get_normalized_metadata(file_path1)
target_dir = './model_06_NN_RFE/'
sonya.createFolder(target_dir)

properties = [  # total 18
    #     'sex',
    #     'age',
    #     'LR',
    'cT',
    'cN',
    'cAverage',
    'cSD',
    #     'aAverage',
#         'aSD',
#         'lMax',
    #     'homogeneous',
    #     'hetero',
    #     'rim',
    #     'clustered',
    #     'non-mass',
    'AorCa'
#         'LymAo',
#         'LymCa'
]

num_properties = len(properties)

X_train = meta_train[properties]
y_train = meta_train['label']

X_test = meta_test[properties]
y_test = meta_test['label']

num_features = len(properties)

batch_size = 25
learning_rate = 0.005
layer1 = 11
layer2 = 11
roc_result = 0
# Out:
# This is local file

# %%
while roc_result < 0.89:
    my_model = mlp_model(num_features, lr=learning_rate, l1=layer1, l2=layer2)
    # roc_result = cross_validation(my_model, X_train, y_train, nbatch=batch_size, nlr=learning_rate, l1=layer1, l2=layer2)
    # def cross_validation(model, X, y, nfold=10, nbatch=5, nlr=0.001, l1=16, l2=16):
    kfold = StratifiedKFold(n_splits=10, shuffle=True)
    accuracy = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    # K-fold cross validation
    # 학습 데이터를 이용해서 학습

    i = 1
    for train_index, validation_index in kfold.split(X_train, y_train):
        kX_train, kX_test = X_train.iloc[train_index], X_train.iloc[validation_index]
        ky_train, ky_test = y_train.iloc[train_index], y_train.iloc[validation_index]

        print("======================batch: {}, lr = {}, FOLD: {}====================".format(batch_size, learning_rate, i))
        cbks = [callbacks.LearningRateScheduler(lambda epoch: 0.001 * 0.5 ** (epoch // 2)),
                callbacks.TensorBoard(write_graph=False)]
        # hist = model.fit(kX_train, ky_train, epochs=500, batch_size=5, validation_data=(kX_test,ky_test),callbacks=[tb_hist])
        my_model.fit(kX_train, ky_train, epochs=500, batch_size=batch_size, validation_data=(kX_test, ky_test),
                     callbacks=cbks,
                     verbose=0)
        y_val_cat_prob = my_model.predict_proba(kX_test)

        k_accuracy = '%.4f' % (my_model.evaluate(kX_test, ky_test)[1])
        accuracy.append(k_accuracy)

        # roc curve
        fpr, tpr, t = roc_curve(y_train.iloc[validation_index], y_val_cat_prob)
        tprs.append(interp(mean_fpr, fpr, tpr))
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
   
        i = i + 1

        # 전체 검증 결과 출력

        # Assigning columns namese
        #     cm_df = pd.DataFrame(cm, columns = )

        test_loss, test_acc = my_model.evaluate(kX_test, ky_test)
    #         test_acc_str = 'cross_validation_test acuracy: {}'.format(test_acc)
        # print('Test acuracy: {}'.format(test_acc))
    #         print(test_acc_str)
        print('\nK-fold cross validation Accuracy: {}'.format(test_acc))

    
    y_pred_proba = (my_model.predict(X_train) >= 0.693).astype(int)
    cm = confusion_matrix(y_train, y_pred_proba)
    print("Radiologist + AI")
    print(cm)
    confusion_metrics(cm)

    mean_tpr = np.mean(tprs, axis=0)
    mean_auc = auc(mean_fpr, mean_tpr)
    roc_result = mean_auc
    print(roc_result)

    current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    model_name = target_dir + 'AUC' +str(int(float(mean_auc) * 100)) + "_" + current_time
    model_json = my_model.to_json()

    with open('{}.json'.format(model_name), 'w') as json_file:
        json_file.write(model_json)  # save model per fold

    my_model.save_weights('{}.h5'.format(model_name))  # save weight per fold

#     plt.plot(mean_fpr, mean_tpr, color='red', label=r'radiologist + AI(AUC = %0.2f)' % (mean_auc), lw=2, alpha=1)


    terminate_time = timeit.default_timer()  # 종료 시간 체크

    total_time = terminate_time - start_time

    # output running time in a nice format.
    mins, secs = divmod(total_time, 60)
    hours, mins = divmod(mins, 60)

    print("Total running time: %d:%d:%d.\n" % (hours, mins, secs))

    x_bar = np.mean(aucs)
    s = np.std(aucs)
    n = len(aucs)

    z = 1.96
    lower = x_bar - (z * (s / sqrt(n)))
    upper = x_bar + (z * (s / sqrt(n)))
    # interval = z * sqrt( (test_acc * (1 - test_acc)) / len(meta_test))
    print(lower, upper)
# Out:
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 65us/step
# 20/20 [==============================] - 0s 96us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 97us/step
# 20/20 [==============================] - 0s 115us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 104us/step
# 20/20 [==============================] - 0s 113us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 94us/step
# 20/20 [==============================] - 0s 103us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 104us/step
# 20/20 [==============================] - 0s 100us/step
#
# K-fold cross validation Accuracy: 0.949999988079071
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 111us/step
# 20/20 [==============================] - 0s 126us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 120us/step
# 19/19 [==============================] - 0s 132us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 114us/step
# 19/19 [==============================] - 0s 106us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 116us/step
# 19/19 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 99us/step
# 19/19 [==============================] - 0s 111us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# Radiologist + AI
# [[ 55   4]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 55
# False Positives: 4
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.82
# 0.8608003108003107
# Total running time: 0:20:15.
#
# 0.818663293760981 0.9017030066053195
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 111us/step
# 20/20 [==============================] - 0s 110us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 88us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 98us/step
# 20/20 [==============================] - 0s 126us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 108us/step
# 20/20 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.949999988079071
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 126us/step
# 20/20 [==============================] - 0s 128us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 99us/step
# 20/20 [==============================] - 0s 106us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 112us/step
# 19/19 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 138us/step
# 19/19 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 1.0
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 101us/step
# 19/19 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 117us/step
# 19/19 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.5789473652839661
# Radiologist + AI
# [[ 54   5]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 54
# False Positives: 5
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.92
# Precision: 0.92
# f_1 Score: 0.81
# 0.8620990120990122
# Total running time: 0:26:25.
#
# 0.7986543386944777 0.9244592144190756
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 124us/step
# 20/20 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 101us/step
# 20/20 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 101us/step
# 20/20 [==============================] - 0s 111us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 99us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 146us/step
# 20/20 [==============================] - 0s 124us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 101us/step
# 20/20 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 127us/step
# 19/19 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 98us/step
# 19/19 [==============================] - 0s 119us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 104us/step
# 19/19 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 112us/step
# 19/19 [==============================] - 0s 92us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# Radiologist + AI
# [[55  4]
#  [39 98]]
# True Positives: 98
# True Negatives: 55
# False Positives: 4
# False Negatives: 39
# --------------------------------------------------
# Accuracy: 0.78
# Mis-Classification: 0.22
# Sensitivity: 0.72
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.81
# 0.8866244866244866
# Total running time: 0:32:35.
#
# 0.8577812702322153 0.9149659825150375
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 123us/step
# 20/20 [==============================] - 0s 109us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 114us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 98us/step
# 20/20 [==============================] - 0s 115us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 108us/step
# 20/20 [==============================] - 0s 120us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 123us/step
# 20/20 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 109us/step
# 20/20 [==============================] - 0s 113us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 130us/step
# 19/19 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 91us/step
# 19/19 [==============================] - 0s 100us/step
#
# K-fold cross validation Accuracy: 1.0
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 101us/step
# 19/19 [==============================] - 0s 126us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 130us/step
# 19/19 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# Radiologist + AI
# [[ 55   4]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 55
# False Positives: 4
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.82
# 0.855957930957931
# Total running time: 0:38:45.
#
# 0.799853174631149 0.9106230158450415
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 108us/step
# 20/20 [==============================] - 0s 126us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 135us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 105us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 100us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 97us/step
# 20/20 [==============================] - 0s 110us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 111us/step
# 19/19 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 129us/step
# 19/19 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 132us/step
# 19/19 [==============================] - 0s 104us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 101us/step
# 19/19 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# Radiologist + AI
# [[56  3]
#  [39 98]]
# True Positives: 98
# True Negatives: 56
# False Positives: 3
# False Negatives: 39
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.72
# Specificity: 0.95
# Precision: 0.95
# f_1 Score: 0.82
# 0.8577644577644578
# Total running time: 0:44:56.
#
# 0.8058396911559232 0.9080797227634906
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 80us/step
# 20/20 [==============================] - 0s 62us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 135us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 98us/step
# 20/20 [==============================] - 0s 128us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 99us/step
# 20/20 [==============================] - 0s 124us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 108us/step
# 20/20 [==============================] - 0s 105us/step
#
# K-fold cross validation Accuracy: 0.550000011920929
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 108us/step
# 20/20 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 138us/step
# 19/19 [==============================] - 0s 119us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 105us/step
# 19/19 [==============================] - 0s 124us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 107us/step
# 19/19 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 107us/step
# 19/19 [==============================] - 0s 130us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# Radiologist + AI
# [[57  2]
#  [40 97]]
# True Positives: 97
# True Negatives: 57
# False Positives: 2
# False Negatives: 40
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.71
# Specificity: 0.97
# Precision: 0.97
# f_1 Score: 0.82
# 0.8396159396159396
# Total running time: 0:51:6.
#
# 0.7718362165803088 0.9054165306724384
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 114us/step
# 20/20 [==============================] - 0s 120us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 116us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 124us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 101us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 104us/step
# 20/20 [==============================] - 0s 128us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 126us/step
# 19/19 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 114us/step
# 19/19 [==============================] - 0s 163us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 111us/step
# 19/19 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 101us/step
# 19/19 [==============================] - 0s 111us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# Radiologist + AI
# [[ 55   4]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 55
# False Positives: 4
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.82
# 0.8514568764568763
# Total running time: 0:57:16.
#
# 0.7862637073108775 0.9147985637513937
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 105us/step
# 20/20 [==============================] - 0s 102us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 110us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 102us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 111us/step
# 20/20 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 96us/step
# 20/20 [==============================] - 0s 133us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 107us/step
# 20/20 [==============================] - 0s 106us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 116us/step
# 19/19 [==============================] - 0s 110us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 117us/step
# 19/19 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 103us/step
# 19/19 [==============================] - 0s 104us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 107us/step
# 19/19 [==============================] - 0s 113us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# Radiologist + AI
# [[56  3]
#  [40 97]]
# True Positives: 97
# True Negatives: 56
# False Positives: 3
# False Negatives: 40
# --------------------------------------------------
# Accuracy: 0.78
# Mis-Classification: 0.22
# Sensitivity: 0.71
# Specificity: 0.95
# Precision: 0.95
# f_1 Score: 0.81
# 0.8704156954156956
# Total running time: 1:3:27.
#
# 0.8377851932833005 0.901555466057359
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 91us/step
# 20/20 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 139us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 96us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 115us/step
# 20/20 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 102us/step
# 20/20 [==============================] - 0s 103us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 155us/step
# 20/20 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 111us/step
# 19/19 [==============================] - 0s 109us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 118us/step
# 19/19 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 130us/step
# 19/19 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 162us/step
# 19/19 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# Radiologist + AI
# [[ 54   5]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 54
# False Positives: 5
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.92
# Precision: 0.92
# f_1 Score: 0.81
# 0.8890415140415139
# Total running time: 1:9:37.
#
# 0.8370408591266858 0.939735697649871
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 91us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 90us/step
# 20/20 [==============================] - 0s 131us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 105us/step
# 20/20 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 104us/step
# 20/20 [==============================] - 0s 109us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 91us/step
# 20/20 [==============================] - 0s 95us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 92us/step
# 20/20 [==============================] - 0s 111us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 112us/step
# 19/19 [==============================] - 0s 113us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 99us/step
# 19/19 [==============================] - 0s 119us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 101us/step
# 19/19 [==============================] - 0s 113us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 110us/step
# 19/19 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# Radiologist + AI
# [[56  3]
#  [39 98]]
# True Positives: 98
# True Negatives: 56
# False Positives: 3
# False Negatives: 39
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.72
# Specificity: 0.95
# Precision: 0.95
# f_1 Score: 0.82
# 0.8556166056166056
# Total running time: 1:15:47.
#
# 0.7895846507495579 0.920122308957402
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 117us/step
# 20/20 [==============================] - 0s 105us/step
#
# K-fold cross validation Accuracy: 0.5
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 104us/step
# 20/20 [==============================] - 0s 115us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 104us/step
# 20/20 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 115us/step
# 20/20 [==============================] - 0s 110us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 98us/step
# 20/20 [==============================] - 0s 103us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 110us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 102us/step
# 19/19 [==============================] - 0s 127us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 99us/step
# 19/19 [==============================] - 0s 103us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 107us/step
# 19/19 [==============================] - 0s 110us/step
#
# K-fold cross validation Accuracy: 0.6315789222717285
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 120us/step
# 19/19 [==============================] - 0s 104us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# Radiologist + AI
# [[ 55   4]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 55
# False Positives: 4
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.82
# 0.8684371184371185
# Total running time: 1:21:57.
#
# 0.8103394385210739 0.9251184369368014
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 93us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.550000011920929
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 105us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 119us/step
# 20/20 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 115us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 115us/step
# 20/20 [==============================] - 0s 114us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 100us/step
# 19/19 [==============================] - 0s 137us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 108us/step
# 19/19 [==============================] - 0s 115us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 110us/step
# 19/19 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 124us/step
# 19/19 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# Radiologist + AI
# [[54  5]
#  [38 99]]
# True Positives: 99
# True Negatives: 54
# False Positives: 5
# False Negatives: 38
# --------------------------------------------------
# Accuracy: 0.78
# Mis-Classification: 0.22
# Sensitivity: 0.72
# Specificity: 0.92
# Precision: 0.92
# f_1 Score: 0.81
# 0.862101787101787
# Total running time: 1:28:7.
#
# 0.806230971117778 0.916516281629475
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 83us/step
# 20/20 [==============================] - 0s 91us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 94us/step
# 20/20 [==============================] - 0s 97us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 105us/step
# 20/20 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 104us/step
# 20/20 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 134us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 88us/step
# 20/20 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 123us/step
# 19/19 [==============================] - 0s 129us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 117us/step
# 19/19 [==============================] - 0s 97us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 109us/step
# 19/19 [==============================] - 0s 109us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 121us/step
# 19/19 [==============================] - 0s 119us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# Radiologist + AI
# [[ 54   5]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 54
# False Positives: 5
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.92
# Precision: 0.92
# f_1 Score: 0.81
# 0.8442751692751691
# Total running time: 1:34:18.
#
# 0.7914514856693549 0.8952151809973119
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 91us/step
# 20/20 [==============================] - 0s 116us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 112us/step
# 20/20 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 98us/step
# 20/20 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 101us/step
# 20/20 [==============================] - 0s 100us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 105us/step
# 20/20 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 100us/step
# 20/20 [==============================] - 0s 100us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 108us/step
# 19/19 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.9473684430122375
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 101us/step
# 19/19 [==============================] - 0s 143us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 108us/step
# 19/19 [==============================] - 0s 131us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 124us/step
# 19/19 [==============================] - 0s 196us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# Radiologist + AI
# [[55  4]
#  [39 98]]
# True Positives: 98
# True Negatives: 55
# False Positives: 4
# False Negatives: 39
# --------------------------------------------------
# Accuracy: 0.78
# Mis-Classification: 0.22
# Sensitivity: 0.72
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.81
# 0.8628510378510377
# Total running time: 1:40:28.
#
# 0.8162052021571878 0.9080438820918967
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 65us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.5
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 102us/step
# 20/20 [==============================] - 0s 103us/step
#
# K-fold cross validation Accuracy: 0.949999988079071
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 127us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 127us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 107us/step
# 20/20 [==============================] - 0s 106us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 107us/step
# 19/19 [==============================] - 0s 128us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 114us/step
# 19/19 [==============================] - 0s 133us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 96us/step
# 19/19 [==============================] - 0s 126us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 111us/step
# 19/19 [==============================] - 0s 125us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# Radiologist + AI
# [[56  3]
#  [38 99]]
# True Positives: 99
# True Negatives: 56
# False Positives: 3
# False Negatives: 38
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.72
# Specificity: 0.95
# Precision: 0.95
# f_1 Score: 0.82
# 0.862074037074037
# Total running time: 1:46:38.
#
# 0.8103590722669833 0.9126812207733097
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 109us/step
# 20/20 [==============================] - 0s 192us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 106us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 105us/step
# 20/20 [==============================] - 0s 134us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 109us/step
# 20/20 [==============================] - 0s 124us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 113us/step
#
# K-fold cross validation Accuracy: 0.949999988079071
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 118us/step
# 20/20 [==============================] - 0s 97us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 107us/step
# 19/19 [==============================] - 0s 134us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 128us/step
# 19/19 [==============================] - 0s 133us/step
#
# K-fold cross validation Accuracy: 0.6315789222717285
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 102us/step
# 19/19 [==============================] - 0s 134us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 106us/step
# 19/19 [==============================] - 0s 143us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# Radiologist + AI
# [[ 55   4]
#  [ 36 101]]
# True Positives: 101
# True Negatives: 55
# False Positives: 4
# False Negatives: 36
# --------------------------------------------------
# Accuracy: 0.8
# Mis-Classification: 0.2
# Sensitivity: 0.74
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.82
# 0.8489094239094239
# Total running time: 1:52:49.
#
# 0.7863278080218071 0.9102655985715996
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 111us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 90us/step
# 20/20 [==============================] - 0s 113us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 107us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 103us/step
# 20/20 [==============================] - 0s 144us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 216us/step
#
# K-fold cross validation Accuracy: 0.949999988079071
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 108us/step
# 19/19 [==============================] - 0s 110us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 113us/step
# 19/19 [==============================] - 0s 106us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 101us/step
# 19/19 [==============================] - 0s 137us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 101us/step
# 19/19 [==============================] - 0s 109us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# Radiologist + AI
# [[56  3]
#  [38 99]]
# True Positives: 99
# True Negatives: 56
# False Positives: 3
# False Negatives: 38
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.72
# Specificity: 0.95
# Precision: 0.95
# f_1 Score: 0.82
# 0.8636086136086136
# Total running time: 1:59:0.
#
# 0.7822094743588731 0.9436147014653028
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 119us/step
#
# K-fold cross validation Accuracy: 0.550000011920929
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 101us/step
# 20/20 [==============================] - 0s 149us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 94us/step
# 20/20 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 114us/step
# 20/20 [==============================] - 0s 111us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 100us/step
# 20/20 [==============================] - 0s 104us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 105us/step
# 20/20 [==============================] - 0s 114us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 110us/step
# 19/19 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 109us/step
# 19/19 [==============================] - 0s 141us/step
#
# K-fold cross validation Accuracy: 0.9473684430122375
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# ...
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 123us/step
# 20/20 [==============================] - 0s 104us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 99us/step
# 20/20 [==============================] - 0s 110us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 93us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 93us/step
# 20/20 [==============================] - 0s 135us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 121us/step
# 20/20 [==============================] - 0s 112us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 114us/step
# 19/19 [==============================] - 0s 113us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 137us/step
# 19/19 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 1.0
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 109us/step
# 19/19 [==============================] - 0s 158us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 130us/step
# 19/19 [==============================] - 0s 152us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# Radiologist + AI
# [[56  3]
#  [38 99]]
# True Positives: 99
# True Negatives: 56
# False Positives: 3
# False Negatives: 38
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.72
# Specificity: 0.95
# Precision: 0.95
# f_1 Score: 0.82
# 0.8517843267843267
# Total running time: 2:29:51.
#
# 0.7677340286549108 0.934170733249851
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 93us/step
# 20/20 [==============================] - 0s 120us/step
#
# K-fold cross validation Accuracy: 0.550000011920929
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 108us/step
# 20/20 [==============================] - 0s 132us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 116us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 112us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 109us/step
# 20/20 [==============================] - 0s 132us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 111us/step
# 20/20 [==============================] - 0s 138us/step
#
# K-fold cross validation Accuracy: 0.949999988079071
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 105us/step
# 19/19 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.6315789222717285
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 126us/step
# 19/19 [==============================] - 0s 124us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 102us/step
# 19/19 [==============================] - 0s 116us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 120us/step
# 19/19 [==============================] - 0s 134us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# Radiologist + AI
# [[ 55   4]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 55
# False Positives: 4
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.82
# 0.8439116439116441
# Total running time: 2:36:2.
#
# 0.7741028261821319 0.9121975401182345
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 117us/step
# 20/20 [==============================] - 0s 99us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 101us/step
# 20/20 [==============================] - 0s 114us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 99us/step
# 20/20 [==============================] - 0s 111us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 94us/step
# 20/20 [==============================] - 0s 129us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 85us/step
# 20/20 [==============================] - 0s 105us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 105us/step
# 20/20 [==============================] - 0s 133us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 96us/step
# 19/19 [==============================] - 0s 129us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 126us/step
# 19/19 [==============================] - 0s 124us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 119us/step
# 19/19 [==============================] - 0s 136us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 116us/step
# 19/19 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# Radiologist + AI
# [[ 54   5]
#  [ 37 100]]
# True Positives: 100
# True Negatives: 54
# False Positives: 5
# False Negatives: 37
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.73
# Specificity: 0.92
# Precision: 0.92
# f_1 Score: 0.81
# 0.8758547008547009
# Total running time: 2:42:12.
#
# 0.840110562576095 0.909816177350645
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 90us/step
# 20/20 [==============================] - 0s 86us/step
#
# K-fold cross validation Accuracy: 0.5
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 95us/step
# 20/20 [==============================] - 0s 103us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 116us/step
# 20/20 [==============================] - 0s 102us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 108us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 125us/step
# 20/20 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 105us/step
# 19/19 [==============================] - 0s 115us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 120us/step
# 19/19 [==============================] - 0s 114us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 121us/step
# 19/19 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.9473684430122375
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 106us/step
# 19/19 [==============================] - 0s 119us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# Radiologist + AI
# [[54  5]
#  [38 99]]
# True Positives: 99
# True Negatives: 54
# False Positives: 5
# False Negatives: 38
# --------------------------------------------------
# Accuracy: 0.78
# Mis-Classification: 0.22
# Sensitivity: 0.72
# Specificity: 0.92
# Precision: 0.92
# f_1 Score: 0.81
# 0.8626262626262625
# Total running time: 2:48:22.
#
# 0.8087009795663691 0.9145957237303342
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 94us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.6499999761581421
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 106us/step
# 20/20 [==============================] - 0s 109us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 96us/step
# 20/20 [==============================] - 0s 127us/step
#
# K-fold cross validation Accuracy: 0.699999988079071
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 126us/step
# 20/20 [==============================] - 0s 125us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 107us/step
# 20/20 [==============================] - 0s 122us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 100us/step
# 20/20 [==============================] - 0s 107us/step
#
# K-fold cross validation Accuracy: 0.8500000238418579
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 98us/step
# 19/19 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.8947368264198303
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 120us/step
# 19/19 [==============================] - 0s 119us/step
#
# K-fold cross validation Accuracy: 0.7368420958518982
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 100us/step
# 19/19 [==============================] - 0s 140us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 113us/step
# 19/19 [==============================] - 0s 117us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# Radiologist + AI
# [[57  2]
#  [40 97]]
# True Positives: 97
# True Negatives: 57
# False Positives: 2
# False Negatives: 40
# --------------------------------------------------
# Accuracy: 0.79
# Mis-Classification: 0.21
# Sensitivity: 0.71
# Specificity: 0.97
# Precision: 0.97
# f_1 Score: 0.82
# 0.865848040848041
# Total running time: 2:54:33.
#
# 0.836032770576801 0.8940771195330893
# ======================batch: 25, lr = 0.005, FOLD: 1====================
# 20/20 [==============================] - 0s 113us/step
# 20/20 [==============================] - 0s 109us/step
#
# K-fold cross validation Accuracy: 0.6000000238418579
# ======================batch: 25, lr = 0.005, FOLD: 2====================
# 20/20 [==============================] - 0s 120us/step
# 20/20 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.8999999761581421
# ======================batch: 25, lr = 0.005, FOLD: 3====================
# 20/20 [==============================] - 0s 111us/step
# 20/20 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 4====================
# 20/20 [==============================] - 0s 100us/step
# 20/20 [==============================] - 0s 108us/step
#
# K-fold cross validation Accuracy: 0.800000011920929
# ======================batch: 25, lr = 0.005, FOLD: 5====================
# 20/20 [==============================] - 0s 133us/step
# 20/20 [==============================] - 0s 115us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 6====================
# 20/20 [==============================] - 0s 130us/step
# 20/20 [==============================] - 0s 106us/step
#
# K-fold cross validation Accuracy: 0.75
# ======================batch: 25, lr = 0.005, FOLD: 7====================
# 19/19 [==============================] - 0s 107us/step
# 19/19 [==============================] - 0s 121us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# ======================batch: 25, lr = 0.005, FOLD: 8====================
# 19/19 [==============================] - 0s 91us/step
# 19/19 [==============================] - 0s 118us/step
#
# K-fold cross validation Accuracy: 0.8421052694320679
# ======================batch: 25, lr = 0.005, FOLD: 9====================
# 19/19 [==============================] - 0s 111us/step
# 19/19 [==============================] - 0s 120us/step
#
# K-fold cross validation Accuracy: 0.7894737124443054
# ======================batch: 25, lr = 0.005, FOLD: 10====================
# 19/19 [==============================] - 0s 111us/step
# 19/19 [==============================] - 0s 123us/step
#
# K-fold cross validation Accuracy: 0.6842105388641357
# Radiologist + AI
# [[ 55   4]
#  [ 36 101]]
# True Positives: 101
# True Negatives: 55
# False Positives: 4
# False Negatives: 36
# --------------------------------------------------
# Accuracy: 0.8
# Mis-Classification: 0.2
# Sensitivity: 0.74
# Specificity: 0.93
# Precision: 0.93
# f_1 Score: 0.82
# 0.8927322677322678
# Total running time: 3:0:43.
#
# 0.852896501883546 0.9315357325486887

# %%
x_bar = np.mean(aucs)
s = np.std(aucs)
n = len(aucs)

z = 1.96
lower = x_bar - (z * (s / sqrt(n)))
upper = x_bar + (z * (s / sqrt(n)))
# interval = z * sqrt( (test_acc * (1 - test_acc)) / len(meta_test))

# %%
x_bar , s
# Out:
# (0.8922161172161174, 0.06343854141459415)

# %%
aucs
# Out:
# [0.9404761904761906,
#  1.0,
#  0.9285714285714286,
#  0.7976190476190476,
#  0.8571428571428572,
#  0.8690476190476191,
#  0.7857142857142857,
#  0.935897435897436,
#  0.9230769230769231,
#  0.8846153846153847]

# %%
print(lower, upper)
# Out:
# 0.852896501883546 0.9315357325486887
